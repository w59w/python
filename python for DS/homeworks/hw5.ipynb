# %%
# task 1
task1 = [1, 2, 3, 4, 5]
for i in task1:
    if i % 2 == 0:
        task1.remove(i)
print(task1)

# %%
# task 2
n = int(input("vvedite chislo: "))
l2 = list(range(1, n + 1))
for i in l2:
    i = str(i)
    l2.append(i)
print(l2)

# %%
# task 3
l2 = ['1', '20', '3', '40', '5']

# %%
# task 4

# %%
# task 5

# %%
# task 6

# %%
# task 7

# %%
# task 8

# %%
# task 9

# %%
# task 10

# %%
# task 11

# %%
# task 12

# %%
# task 13

# %%
# task 14

# %%
# task 15

# %%
# task 16

# %%
# task 17

# %%
# task 18

# %%
# task 19

# %%
# task 20

# %%
# task 21
