# %%
# task 1
"""Создайте список list_ с пятью элементами. Затем присвойте третий элемент этого списка переменной list1"""
list_ = [1, 2, 3, 4, 5]
list1 = list_[3]
print(list1)

# %%
# task 2
"""Дан список list2.

Oтсортируйте его в возрастающем порядке и удалите элемент, который будет находится по середине."""
list2 = [23, 34, 12, 7, 0, -4, -56, -100, 344, 98, 232]
list2 = sorted(list2)
print(list2)
mid = len(list2) // 2
list2.pop(mid)
print(list2)

# %%
# task 3
"""Дан список list_ и переменная num со значением input(). Посчитайте, сколько раз элемент, который придет в num, встречается в списке. Oтвет запишите в переменную list3."""
list_ = [1, 22, 3, 45, 22, 4, 89, 87, 87, 4]
num = int(input("vvedite chislo: "))
list3 = []
if num in list_:
    list3 = list_.count(num)
else:
    print("takogo chisla net.")

# %%
# task 4
"""Представьте себе, что у вас есть сад с фруктами. Соберите 5 фруктов из этого сада в корзину (список list4), используя метод добавления в списки. Затем замените третий(index = 2) элемент на другой фрукт через метод списка."""
list4 = []
list4.append("apple")
list4.append("pinapple")
list4.append("plum")
list4.append("banana")
list4.append("cherry")
print(list4)
list4[2] = "pear"
print(list4)
# Out:
# ['apple', 'pinapple', 'plum', 'banana', 'cherry']

# %%
# task 5
"""Создайте список list5 заполненныый числами от 0 до 19 включительно используя range() так, чтобы не было вложенностей."""
list5 = list(range(0, 20))
print(list5)

# %%
# task 6
"""Создайте два списка ls1, ls2 со случайным набором чисел. Объедините эти списки в один, азатем присвойте сумму всех чисел переменной list6."""
ls1 = [1, 8, 4]
ls2 = [5, 7, 3]
ls3 = ls1 + ls2
list6 = sum(ls3)
print(list6)
# Out:
# 28

# %%
# task 7
"""Дан список lst7. Извлеките из него только те числа, которые больше 10. Ответ запишите в переменную list9. Вам понадобится функция filter(), про которую стоит прочитать в документации или в Google)"""
lst7 = [1, 22, 10, 45, 22, 4, 89, 87, 87, 4]
list7 = list(filter(lambda x: x > 10, lst7))
print(list7)

# %%
# task 8
"""Дана строка str_. Превратите ее в список разбив по пробелу."""
str_ = 'The second type of coordinate system is a projected coordinate system.'

list8 = str_.split(" ")
print(list8)
# Out:
# ['The', 'second', 'type', 'of', 'coordinate', 'system', 'is', 'a', 'projected', 'coordinate', 'system.']
