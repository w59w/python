# %%
# task 1
dict1 = {
    "name": "Kumushai",
    "age": 20,
}
dict1.clear()
print(dict1)
# Out:
# {}

# %%
# task 2
dict2 = {'a': 1, 'b': 2, 'c': 1}
print(dict2.keys())
# Out:
# dict_keys(['a', 'b', 'c'])

# %%
# task 3
dict3 = {'a': 1, 'b': 2, 'c': 1}
for key, value in dict3.items():
    print(key, value)
# Out:
# a 1
# b 2
# c 1

# %%
# task 4
dict4 = {'a': 1, 'b': 4, 'c': 1, 'd': 5, 'e': 6}
new_dict = {}
for key, value in dict4.items():
    if value < 4:
        new_dict[key] = value
print(new_dict)

# %%
# task 5
dict5 = {
    1: {'a': 1},
    2: {'b': 4},
    3: {'c': 1},
    4: {'d': 5},
    5: {'e': 6}
}

# %%
# task 7

# %%
# task 9
