# %% [markdown]
# dict seminar
# # dict comprehension
# {key: value for key, value in
# f({mnojestva}) if {uslovie}}

# %%
# task 1
d = {}
key = "ID_32"
value = "Simon23"
d[key] = value
print(d)
# Out:
# {'ID_32': 'Simon23'}
