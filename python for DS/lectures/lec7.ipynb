# %% [markdown]
# Dict()
# словарь -- изменяемый типа неупорядоченных данных, который состоит из пар элементов.
# KEY : VALUE # ключ:значение
# Отличительной особенностью является наличие фигурных скобок и фигурных скобок и парных элемнтов через двоеточие.
# {
#     key_1 : value_1,
#     key_2 : value_2,
#     key_3 : value_3,
#     ....
# }
# Словари очень частоо используются при решении огромного спектра задач как в работе с данными так и во многих других областях IT. Например сырые данные, которые мы можем получать при API запросе на какой-либо сервер часто имеют расширение JSON, который есть ни
