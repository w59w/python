# %%
class Animal:
    def __init__(self, name):
        self.name = name
    def speak(self):
        return "Animal sound"

class Dog(Animal):
    def speak(self):
        return "Woof"

a = Animal("Unknown")
d = Dog("Rex")

print(a.speak())
print(d.speak())
# Out:
# Animal sound
# Woof

# %%
def count_words(text):
    words = text.split()
    return len(words)

print(count_words("Python is very cool"))
# Out:
# 4

# %%
class TextAnalyzer:
    def __init__(self, text):
        self.text = text
    def analyze(self):
        return count_words(self.text)

analyzer = TextAnalyzer("I love Pyhton")
print(analyzer.analyze())
# Out:
# 3
